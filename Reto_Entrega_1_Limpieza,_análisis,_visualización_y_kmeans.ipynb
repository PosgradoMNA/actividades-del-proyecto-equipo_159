# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-del-proyecto-equipo_159/blob/main/Reto_Entrega_1_Limpieza%2C_an%C3%A1lisis%2C_visualizaci%C3%B3n_y_kmeans.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Reto-Entrega 1 - Limpieza, análisis, visualización y kmeans**
# ###**Equipo 159:**
#
# ###**Daniela Parra García A01633687**
# ###**Jaime Andrés Palacios Campaña A01794023**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
path = 'https://github.com/PosgradoMNA/actividades-del-proyecto-equipo_159/blob/main/Datos_de_calidad_del_agua_de_sitios_de_monitoreo_de_aguas_superficiales_2020.csv'

path_df = pd.read_csv(path, sep=",",
                      lineterminator='\r',
                      error_bad_lines=False)

#Copiamos el dataframe con los datos originales para tener su backup.
df = path_df.copy()

df.info()
df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Columns: 548 entries,
#
#
#
#
#
#
# <!DOCTYPE html>
# <html lang="en" data-color-mode="auto" data-light-theme="light" data-dark-theme="dark" data-a11y-animated-images="system">
#   <head>
#     <meta charset="utf-8">
#   <link rel="dns-prefetch" href="https://github.githubassets.com">
#   <link rel="dns-prefetch" href="https://avatars.githubusercontent.com">
#   <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">
#   <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">
#   <link rel="preconnect" href="https://github.githubassets.com" crossorigin>
#   <link rel="preconnect" href="https://avatars.githubusercontent.com">
#
#
#
# ...
